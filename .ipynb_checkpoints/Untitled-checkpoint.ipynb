# %%
import numpy as np

# %%
x=np.linspace(0,1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,x)

# %%
print(np.__version__)
# Out:
# 1.22.4

# %%
help('jupyterlab')
# Out:
# Help on package jupyterlab:
#
# NAME
#     jupyterlab - Server extension for JupyterLab.
#
# PACKAGE CONTENTS
#     __main__
#     _version
#     browser_check
#     commands
#     coreconfig
#     debuglog
#     federated_labextensions
#     handlers (package)
#     jlpmapp
#     labapp
#     labextensions
#     labhubapp
#     pytest_plugin
#     semver
#     serverextension
#     tests (package)
#     upgrade_extension
#     utils
#
# VERSION
#     3.4.3
#
# FILE
#     d:\python\env\wslpython\lib\site-packages\jupyterlab\__init__.py

# %%
help('jupytext')
# Out:
# Help on package jupytext:
#
# NAME
#     jupytext - Read and write Jupyter notebooks as text files
#
# PACKAGE CONTENTS
#     __main__
#     cell_metadata
#     cell_reader
#     cell_to_text
#     cli
#     combine
#     compare
#     config
#     contentsmanager
#     doxygen
#     formats
#     header
#     jupytext
#     kernels
#     languages
#     magics
#     metadata_filter
#     myst
#     paired_paths
#     pairs
#     pandoc
#     pep8
#     quarto
#     reraise
#     stringparser
#     version
#
# CLASSES
#     jupyter_server.services.contents.largefilemanager.LargeFileManager(jupyter_server.services.contents.filemanager.FileContentsManager)
#         jupytext.contentsmanager.JupytextContentsManager(jupyter_server.services.contents.largefilemanager.LargeFileManager, jupytext.config.JupytextConfiguration)
#     jupytext.config.JupytextConfiguration(traitlets.config.configurable.Configurable)
# ...
